# %%
# Esteban Quintero Sotomayor - 20110388.

import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Read Multiple sheets
dictDf = pd.read_excel('Canada.xlsx', sheet_name = ['Regions by Citizenship', 'Canada by Citizenship', 'Canada by Citizenship2'])

# Get DataFrame from Dict
regionsByCitizenshipDf = dictDf.get('Regions by Citizenship')
canadaByCitizenshipDf = dictDf.get('Canada by Citizenship')
canadaByCitizenship2Df = dictDf.get('Canada by Citizenship2')

# %%
# Print first DataFrame = first sheet
regionsByCitizenshipDf
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                      United Nations         NaN
# 4                                 Population Division         NaN
# 5           Department of Economic and Social Affairs         NaN
# 6                                                 NaN         NaN
# 7   International Migration Flows to and from Sele...         NaN
# 8                                                 NaN         NaN
# 9                            POP/DB/MIG/Flow/Rev.2015         NaN
# 10  December 2015 - Copyright © 2015 by United Nat...         NaN
# 11  Suggested citation: United Nations, Department...         NaN
# 12   International Migration Flows to and from Sel...         NaN
# ...

# %%
# Drop specific rows range, in this case from 0 to 18. Not hardcode axis needed, implicit axis = 0 = rows
regionsByCitizenshipDf = regionsByCitizenshipDf.drop(range(0, 19))

# %%
regionsByCitizenshipDf
# Out:
#     Unnamed: 0  Unnamed: 1                             Unnamed: 2  \
# 19        Type    Coverage                               AreaName
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# ...

# %%
# For easiest reading
regionsByCitizenshipDf.head()
# Out:
#     Unnamed: 0  Unnamed: 1        Unnamed: 2        Unnamed: 3 Unnamed: 4  \
# 19        Type    Coverage          AreaName           RegName       1980
# 20  Immigrants    Citizens  Northern America  Northern America         ..
# 21  Immigrants  Foreigners            Africa    Eastern Africa       1471
# 22  Immigrants  Foreigners            Africa     Middle Africa         33
# 23  Immigrants  Foreigners            Africa   Northern Africa       1100
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28  \
# 19       1981       1982       1983       1984       1985  ...        2004
# 20         ..         ..         ..         ..         ..  ...          ..
# 21       1641       1426       1094       1187       1134  ...        7726
# 22         27         44         32         42         30  ...        2452
# 23       1268       1348        936        842        840  ...       12478
#
# ...

# %%
# Rename columns
headers = ["Unnamed: 0", "Unnamed: 1", "Unnamed: 2", "Unnamed: 3", "Unnamed: 4", "Unnamed: 5", "Unnamed: 6", "Unnamed: 7", "Unnamed: 8", "Unnamed: 9", 
           "Unnamed: 10", "Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15", "Unnamed: 16", "Unnamed: 17", "Unnamed: 18", "Unnamed: 19", 
           "Unnamed: 20", "Unnamed: 21", "Unnamed: 22", "Unnamed: 23", "Unnamed: 24", "Unnamed: 25", "Unnamed: 26", "Unnamed: 27", "Unnamed: 28", "Unnamed: 29", 
           "Unnamed: 30", "Unnamed: 31", "Unnamed: 32", "Unnamed: 33", "Unnamed: 34", "Unnamed: 35", "Unnamed: 36", "Unnamed: 37"]

regionsByCitizenshipDf.columns = headers
regionsByCitizenshipDf = regionsByCitizenshipDf.rename(columns = {'Unnamed: 0':'Type', 'Unnamed: 1':'Coverage', 'Unnamed: 2':'AreaName', 'Unnamed: 3':'RegName', 'Unnamed: 4':'1980', 'Unnamed: 5':'1981', 'Unnamed: 6':'1982', 'Unnamed: 7':'1983', 'Unnamed: 8':'1984', 'Unnamed: 9':'1985',
                                                                  'Unnamed: 10':'1986', 'Unnamed: 11':'1987', 'Unnamed: 12':'1988', 'Unnamed: 13':'1989', 'Unnamed: 14':'1990', 'Unnamed: 15':'1991', 'Unnamed: 16':'1992', 'Unnamed: 17':'1993', 'Unnamed: 18':'1994', 'Unnamed: 19':'1995',
                                                                  'Unnamed: 20':'1996', 'Unnamed: 21':'1997', 'Unnamed: 22':'1998', 'Unnamed: 23':'1999', 'Unnamed: 24':'2000', 'Unnamed: 25':'2001', 'Unnamed: 26':'2002', 'Unnamed: 27':'2003', 'Unnamed: 28':'2004', 'Unnamed: 29':'2005',
                                                                  'Unnamed: 30':'2006', 'Unnamed: 31':'2007', 'Unnamed: 32':'2008', 'Unnamed: 33':'2009', 'Unnamed: 34':'2010', 'Unnamed: 35':'2011', 'Unnamed: 36':'2012', 'Unnamed: 37':'2013'}, inplace = False)

# %%
regionsByCitizenshipDf.head()
# Out:
#           Type    Coverage          AreaName           RegName  1980  1981  \
# 19        Type    Coverage          AreaName           RegName  1980  1981
# 20  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 21  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
# 22  Immigrants  Foreigners            Africa     Middle Africa    33    27
# 23  Immigrants  Foreigners            Africa   Northern Africa  1100  1268
#
#     1982  1983  1984  1985  ...   2004   2005   2006   2007   2008   2009  \
# 19  1982  1983  1984  1985  ...   2004   2005   2006   2007   2008   2009
# 20    ..    ..    ..    ..  ...     ..     ..     ..     ..     ..     ..
# 21  1426  1094  1187  1134  ...   7726   7083   6750   6669   6705   6922
# 22    44    32    42    30  ...   2452   2802   2834   2951   3034   3255
# 23  1348   936   842   840  ...  12478  11323  12705  11750  13456  16320
#
#      2010   2011     2012    2013
# 19   2010   2011   2012.0  2013.0
# ...

# %%
# Delete specific row
regionsByCitizenshipDf.drop(19, axis=0, inplace=True)

# %%
regionsByCitizenshipDf
# Out:
#           Type    Coverage                               AreaName  \
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# 32  Immigrants  Foreigners                             Asia Total
# ...

# %%
# Replace missing data : .. to NaN
regionsByCitizenshipDf.replace("..", np.nan, inplace=True)
regionsByCitizenshipDf
# Out:
#           Type    Coverage                               AreaName  \
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# 32  Immigrants  Foreigners                             Asia Total
# ...

# %%
# Code to find missing data location on Dataframe, NaN
missing_data = regionsByCitizenshipDf.isnull()
columnsWithNan = 0

for column in missing_data.columns.values.tolist():
    if regionsByCitizenshipDf[column].isnull().values.any():
        columnsWithNan = columnsWithNan + 1
        print(column)
        print(missing_data[column].value_counts())
        print("")
        
print("Columns with NaN: ", columnsWithNan)
# Out:
# RegName
# False    24
# True      5
# Name: RegName, dtype: int64
#
# 1980
# False    27
# True      2
# Name: 1980, dtype: int64
#
# 1981
# False    26
# True      3
# Name: 1981, dtype: int64
#
# 1982
# False    26
# True      3
# Name: 1982, dtype: int64
#
# 1983
# False    27
# True      2
# Name: 1983, dtype: int64
#
# 1984
# False    26
# True      3
# Name: 1984, dtype: int64
#
# 1985
# False    26
# True      3
# Name: 1985, dtype: int64
#
# 1986
# False    26
# True      3
# Name: 1986, dtype: int64
#
# 1987
# False    26
# True      3
# Name: 1987, dtype: int64
#
# 1988
# False    27
# True      2
# Name: 1988, dtype: int64
#
# 1989
# False    27
# True      2
# Name: 1989, dtype: int64
#
# 1990
# False    27
# True      2
# Name: 1990, dtype: int64
#
# 1991
# False    27
# True      2
# Name: 1991, dtype: int64
#
# 1992
# False    28
# True      1
# Name: 1992, dtype: int64
#
# 1994
# False    28
# True      1
# Name: 1994, dtype: int64
#
# 1997
# False    27
# ...

# %%
# Loop equal to next scope to don't waste time
missing_data = regionsByCitizenshipDf.isnull()

for column in missing_data.columns.values.tolist():
    if regionsByCitizenshipDf[column].isnull().values.any():
        regionsByCitizenshipDf[column].replace(np.nan, "0", inplace=True)

# %%
# Replace NaN value in whole Dataframe by 0
regionsByCitizenshipDf["RegName"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1980"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1981"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1982"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1983"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1984"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1985"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1986"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1987"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1988"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1989"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1990"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1991"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1992"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1994"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1997"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1998"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["1999"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2000"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2001"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2002"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2003"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2004"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2005"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2006"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2007"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2008"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2009"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2010"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2011"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf["2013"].replace(np.nan, "0", inplace=True)
regionsByCitizenshipDf
# Out:
#           Type    Coverage                               AreaName  \
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# 32  Immigrants  Foreigners                             Asia Total
# ...

# %%
# Replace RegName column fields with value 0 to ""
regionsByCitizenshipDf["RegName"].replace("0", "", inplace=True)
regionsByCitizenshipDf
# Out:
#           Type    Coverage                               AreaName  \
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# 32  Immigrants  Foreigners                             Asia Total
# ...

# %%
regionsByCitizenshipDf.to_excel("P2_T1.xlsx")
